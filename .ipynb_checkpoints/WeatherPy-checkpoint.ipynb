# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
# import openweathermapy.core as owm
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import wkey
from api_keys import gkey

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 649

# %%
# Build the base URL for the OpenWeatherMap URL
url = "http://api.openweathermap.org/data/2.5/weather?"
# We want the units to be shown using the metric system
units = "metric"

# Build partial query URL
query_url = f"{url}appid={wkey}&units={units}&q="

cities_owm = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
min_temp = []
wind_speed = []

# for organization we're going to split the cities into sets of fifty cities:
city_count = 1
city_set_count = 1

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Loop through the list of cities and perform a request for data on each
print(f"Beginning Data Retrieval")
print(f"-----------------------")
for city in cities:
    try:
        response = requests.get(query_url + city.replace(' ','&')).json()
        cities_owm.append(response['name'])
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        min_temp.append(response['main']['temp_min'])
        wind_speed.append(response['wind']['speed'])
    
        if city_count > 49:
            city_count = 1
            city_set_count +=1
        else:
            city_count +=1
        print(f"Processing Record {city_count} of Set {city_set_count} | {city}")
    except Exception:
        print(f"City not found, skipping city...")
print(f"-----------------------")
print(f"Data Retrieval Complete")
print(f"-----------------------")
# Out:
# Beginning Data Retrieval
# -----------------------
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | naryan-mar
# Processing Record 4 of Set 1 | hobart
# Processing Record 5 of Set 1 | harnosand
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | griffith
# Processing Record 8 of Set 1 | upernavik
# Processing Record 9 of Set 1 | levikha
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | hermanus
# Processing Record 12 of Set 1 | grand gaube
# Processing Record 13 of Set 1 | kruisfontein
# Processing Record 14 of Set 1 | tuskegee
# Processing Record 15 of Set 1 | novaya ladoga
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | atuona
# City not found, skipping city...
# Processing Record 18 of Set 1 | baruun-urt
# City not found, skipping city...
# Processing Record 19 of Set 1 | airai
# City not found, skipping city...
# Processing Record 20 of Set 1 | vao
# Processing Record 21 of Set 1 | sitka
# City not found, skipping city...
# Processing Record 22 of Set 1 | kpandu
# City not found, skipping city...
# Processing Record 23 of Set 1 | fethiye
# City not found, skipping city...
# Processing Record 24 of Set 1 | barberton
# Processing Record 25 of Set 1 | chumphon
# Processing Record 26 of Set 1 | jiuquan
# Processing Record 27 of Set 1 | saint-philippe
# Processing Record 28 of Set 1 | richards bay
# Processing Record 29 of Set 1 | praia
# Processing Record 30 of Set 1 | atmakur
# Processing Record 31 of Set 1 | almaznyy
# City not found, skipping city...
# Processing Record 32 of Set 1 | jamestown
# Processing Record 33 of Set 1 | santa ana
# City not found, skipping city...
# City not found, skipping city...
# Processing Record 34 of Set 1 | souillac
# Processing Record 35 of Set 1 | krasne
# Processing Record 36 of Set 1 | punta arenas
# Processing Record 37 of Set 1 | port blair
# Processing Record 38 of Set 1 | saskylakh
# Processing Record 39 of Set 1 | thompson
# Processing Record 40 of Set 1 | victoria
# Processing Record 41 of Set 1 | cabo san lucas
# Processing Record 42 of Set 1 | salisbury
# Processing Record 43 of Set 1 | prince rupert
# Processing Record 44 of Set 1 | caravelas
# Processing Record 45 of Set 1 | klaksvik
# Processing Record 46 of Set 1 | new norfolk
# Processing Record 47 of Set 1 | xining
# Processing Record 48 of Set 1 | tiksi
# City not found, skipping city...
# Processing Record 49 of Set 1 | arraial do cabo
# Processing Record 50 of Set 1 | mataura
# Processing Record 1 of Set 2 | carnarvon
# Processing Record 2 of Set 2 | kavieng
# Processing Record 3 of Set 2 | joshimath
# Processing Record 4 of Set 2 | tasiilaq
# Processing Record 5 of Set 2 | lashio
# Processing Record 6 of Set 2 | aloleng
# Processing Record 7 of Set 2 | cape town
# Processing Record 8 of Set 2 | iqaluit
# Processing Record 9 of Set 2 | rio gallegos
# City not found, skipping city...
# Processing Record 10 of Set 2 | hami
# Processing Record 11 of Set 2 | bredasdorp
# Processing Record 12 of Set 2 | virginia beach
# Processing Record 13 of Set 2 | sardinata
# Processing Record 14 of Set 2 | tuktoyaktuk
# City not found, skipping city...
# Processing Record 15 of Set 2 | punta alta
# Processing Record 16 of Set 2 | whitianga
# City not found, skipping city...
# Processing Record 17 of Set 2 | east london
# Processing Record 18 of Set 2 | dikson
# Processing Record 19 of Set 2 | castro
# Processing Record 20 of Set 2 | avarua
# Processing Record 21 of Set 2 
# Processing Record 47 of Set 3 | riyadh
# Processing Record 48 of Set 3 | vaini
# Processing Record 49 of Set 3 | paso de patria
# Processing Record 50 of Set 3 | miramar
# Processing Record 1 of Set 4 | poirino
# Processing Record 2 of Set 4 | nanortalik
# Processing Record 3 of Set 4 | porto novo
# Processing Record 4 of Set 4 | katsuura
# Processing Record 5 of Set 4 | yellowknife
# Processing Record 6 of Set 4 | nikolskoye
# Processing Record 7 of Set 4 | san rafael
# Processing Record 8 of Set 4 | zherdevka
# Processing Record 9 of Set 4 | port hardy
# Processing Record 10 of Set 4 | severo-kurilsk
# Processing Record 11 of Set 4 | puerto ayora
# Processing Record 12 of Set 4 | yakeshi
# Processing Record 13 of Set 4 | talnakh
# Processing Record 14 of Set 4 | hovd
# City not found, skipping city...
# Processing Record 15 of Set 4 | banda aceh
# City not found, skipping city...
# Processing Record 16 of Set 4 | aurillac
# Processing Record 17 of Set 4 | tete
# Processing Record 18 of Set 4 | warrnambool
# Processing Record 19 of Set 4 | port moresby
# Processing Record 20 of Set 4 | barrow
# Processing Record 21 of Set 4 | anito
# Processing Record 22 of Set 4 | taltal
# Processing Record 23 of Set 4 | mount isa
# Processing Record 24 of Set 4 | chegutu
# Processing Record 25 of Set 4 | mantua
# City not found, skipping city...
# Processing Record 26 of Set 4 | soderhamn
# Processing Record 27 of Set 4 | mahenge
# Processing Record 28 of Set 4 | san vicente
# Processing Record 29 of Set 4 | belaya gora
# Processing Record 30 of Set 4 | chokurdakh
# Processing Record 31 of Set 4 | dunedin
# Processing Record 32 of Set 4 | faya
# Processing Record 33 of Set 4 | pesqueria
# Processing Record 34 of Set 4 | angoche
# Processing Record 35 of Set 4 | hobyo
# Processing Record 36 of Set 4 | ancud
# Processing Record 37 of Set 4 | bima
# Processing Record 38 of Set 4 | bukan
# Processing Record 39 of Set 4 | totness
# Processing Record 40 of Set 4 | san juan bautista
# Processing Record 41 of Set 4 | ajdabiya
# City not found, skipping city...
# Processing Record 42 of Set 4 | bay roberts
# Processing Record 43 of Set 4 | preobrazheniye
# Processing Record 44 of Set 4 | geraldton
# Processing Record 45 of Set 4 | pingliang
# Processing Record 46 of Set 4 | conde
# Processing Record 47 of Set 4 | hohhot
# City not found, skipping city...
# Processing Record 48 of Set 4 | burnie
# City not found, skipping city...
# City not found, skipping city...
# Processing Record 49 of Set 4 | chapais
# Processing Record 50 of Set 4 | murbad
# Processing Record 1 of Set 5 | chuy
# Processing Record 2 of Set 5 | roros
# Processing Record 3 of Set 5 | kuytun
# City not found, skipping city...
# Processing Record 4 of Set 5 | coahuayana
# Processing Record 5 of Set 5 | hof
# City not found, skipping city...
# Processing Record 6 of Set 5 | rancho palos verdes
# Processing Record 7 of Set 5 | norman wells
# Processing Record 8 of Set 5 | west wendover
# Processing Record 9 of Set 5 | santa maria
# Processing Record 10 of Set 5 | dubbo
# Processing Record 11 of Set 5 | nome
# Processing Record 12 of Set 5 | jumla
# Processing Record 13 of Set 5 | celestun
# Processing Record 14 of Set 5 | amga
# Processing Record 15 of Set 5 | buraydah
# Processing Record 16 of Set 5 | maamba
# Processing Record 17 of Set 5 | nouna
# Processing Record 18 of Set 5 | vestmannaeyjar
# Processing Record 19 of Set 5 | sterlibashevo
# Processing Record 20 of Set 5 | birjand
# Processing Record 21 of Set 5 | georgetown
# Processing Record 22 of Set 5 | sao jose do egito
# Processing Record 23 of Set 5 | dingle
# Processing Record 24 of Set 5 | novichikha
# Processing Record 25 of Set 5 | marzuq
# Processing Record 26 of Set 5 | constitucion
# Processing Record 27 of Set 5 | saint-joseph
# Processing Record 28 of Set 5 | kahului
# City not found, skipping city...
# Processing Record 29 of Set 5 | itarema
# City not found, skipping city...
# Processing Record 30 of Set 5 | kulhudhuffushi
# Processing Record 31 of Set 5 | tandalti
# Processing Record 32 of Set 5 | salinas
# Processing Record 33 of Set 5 | marrakesh
# Processing Record 34 of Set 5 | viedma
# Processing Record 35 of Set 5 | esperance
# Processing Record 36 of Set 5 | volodarka
# Processing Record 37 of Set 5 | sisimiut
# Processing Record 38 of Set 5 | kununurra
# Processing Record 39 of Set 5 | pisco
# Processing Record 40 of Set 5 | roma
# Processing Record 41 of Set 5 | atar
# Processing Record 42 of Set 5 | zhigansk
# Processing Record 43 of Set 5 | manzhouli
# Processing Record 44 of Set 5 | gat
# Processing Record 45 of Set 5 | ola
# Processing Record 46 of Set 5 | lazaro cardenas
# Processing Record 47 of Set 5 | ulaanbaatar
# Processing Record 48 of Set 5 | gaoua
# Processing Record 49 of Set 5 | quelimane
# Processing Record 50 of Set 5 | cherskiy
# Processing Record 1 of Set 6 | necochea
# Processing Record 2 of Set 6 | jalu
# City not found, skipping city...
# Processing Record 3 of Set 6 | coquimbo
# City not found, skipping city...
# Processing Record 4 of Set 6 | nelson bay
# Processing Record 5 of Set 6 | santa cruz de la palma
# Processing Record 6 of Set 6 | hurricane
# Processing Record 7 of Set 6 | sibolga
# Processing Record 8 of Set 6 | jhang
# Processing Record 9 of Set 6 | black river
# Processing Record 10 of Set 6 | wattegama
# Processing Record 11 of Set 6 | kaitangata
# Processing Record 12 of Set 6 | hudson bay
# Processing Record 13 of Set 6 | roald
# City not found, skipping city...
# Processing Record 14 of Set 6 | lagos
# City not found, skipping city...
# Processing Record 15 of Set 6 | moron
# Processing Record 16 of Set 6 | port elizabeth
# Processing Record 17 of Set 6 | bardsir
# Processing Record 18 of Set 6 | teguise
# City not found, skipping city...
# Processing Record 19 of Set 6 | north battleford
# Processing Record 20 of Set 6 | bacum
# Processing Record 21 of Set 6 | broome
# Processing Record 22 of Set 6 | ternate
# Processing Record 23 of Set 6 | lebu
# Processing Record 24 of Set 6 | talaya
# Processing Record 25 of Set 6 | sorland
# City not found, skipping city...
# City not found, skipping city...
# City not found, skipping city...
# Processing Record 26 of Set 6 | sioux lookout
# City not found, skipping city...
# Processing Record 27 of Set 6 | byron bay
# Processing Record 28 of Set 6 | rock sound
# Processing Record 29 of Set 6 | paracuru
# Processing Record 30 of Set 6 | grindavik
# Processing Record 31 of Set 6 | daoukro
# Processing Record 32 of Set 6 | leningradskiy
# Processing Record 33 of Set 6 | victoria point
# Processing Record 34 of Set 6 | khor
# Processing Record 35 of Set 6 | miguel calmon
# Processing Record 36 of Set 6 | fort nelson
# Processing Record 37 of Set 6 | lagoa
# Processing Record 38 of Set 6 | merauke
# Processing Record 39 of Set 6 | muros
# Processing Record 40 of Set 6 | rio grande
# City not found, skipping city...
# Processing Record 41 of Set 6 | mayumba
# Processing Record 42 of Set 6 | esik
# Processing Record 43 of Set 6 | ibra
# Processing Record 44 of Set 6 | sao joao da barra
# Processing Record 45 of Set 6 | halifax
# Processing Record 46 of Set 6 | boyolangu
# Processing Record 47 of Set 6 | ahipara
# Processing Record 48 of Set 6 | namibe
# Processing Record 49 of Set 6 | denia
# Processing Record 50 of Set 6 | kieta
# Processing Record 1 of Set 7 | usinsk
# Processing Record 2 of Set 7 | saint-augustin
# Processing Record 3 of Set 7 | mar del plata
# Processing Record 4 of Set 7 | vyselki
# Processing Record 5 of Set 7 | luanda
# Processing Record 6 of Set 7 | sarkand
# Processing Record 7 of Set 7 | tateyama
# Processing Record 8 of Set 7 | awjilah
# Processing Record 9 of Set 7 | lipari
# Processing Record 10 of Set 7 | mattru
# Processing Record 11 of Set 7 | yarmouth
# Processing Record 12 of Set 7 | pavelets
# Processing Record 13 of Set 7 | caohai
# Processing Record 14 of Set 7 | camara de lobos
# Processing Record 15 of Set 7 | san patricio
# Processing Record 16 of Set 7 | bambanglipuro
# City not found, skipping city...
# Processing Record 17 of Set 7 | rio verde de mato grosso
# Processing Record 18 of Set 7 | centralia
# Processing Record 19 of Set 7 | turukhansk
# Processing Record 20 of Set 7 | marawi
# Processing Record 21 of Set 7 | lakes entrance
# Processing Record 22 of Set 7 | casa nova
# Processing Record 23 of Set 7 | amapa
# Processing Record 24 of Set 7 | aquiraz
# Processing Record 25 of Set 7 | taft
# Processing Record 26 of Set 7 | monrovia
# Processing Record 27 of Set 7 | ahuimanu
# Processing Record 28 of Set 7 | slatina-timis
# Processing Record 29 of Set 7 | wenling
# Processing Record 30 of Set 7 | fortuna
# Processing Record 31 of Set 7 | bukama
# Processing Record 32 of Set 7 | boende
# Processing Record 33 of Set 7 | port hawkesbury
# Processing Record 34 of Set 7 | ostrovnoy
# Processing Record 35 of Set 7 | ontario
# Processing Record 36 of Set 7 | gayeri
# Processing Record 37 of Set 7 | saint-gaudens
# Processing Record 38 of Set 7 | superior
# Processing Record 39 of Set 7 | cidreira
# City not found, skipping city...
# Processing Record 40 of Set 7 | bowmore
# Processing Record 41 of Set 7 | saint-pierre
# Processing Record 42 of Set 7 | cockburn town
# Processing Record 43 of Set 7 | balkhash
# Processing Record 44 of Set 7 | ostersund
# Processing Record 8 of Set 9 | herat
# Processing Record 9 of Set 9 | avanigadda
# Processing Record 10 of Set 9 | bennington
# City not found, skipping city...
# Processing Record 11 of Set 9 | praia da vitoria
# Processing Record 12 of Set 9 | antofagasta
# Processing Record 13 of Set 9 | ilulissat
# City not found, skipping city...
# Processing Record 14 of Set 9 | santiago del estero
# Processing Record 15 of Set 9 | srednekolymsk
# Processing Record 16 of Set 9 | canton
# City not found, skipping city...
# Processing Record 17 of Set 9 | yuncheng
# Processing Record 18 of Set 9 | inirida
# Processing Record 19 of Set 9 | dhidhdhoo
# Processing Record 20 of Set 9 | uray
# Processing Record 21 of Set 9 | brownfield
# Processing Record 22 of Set 9 | kargasok
# Processing Record 23 of Set 9 | bontang
# Processing Record 24 of Set 9 | olinda
# Processing Record 25 of Set 9 | tczew
# Processing Record 26 of Set 9 | palmas
# Processing Record 27 of Set 9 | ariquemes
# Processing Record 28 of Set 9 | vilhena
# Processing Record 29 of Set 9 | ozernovskiy
# Processing Record 30 of Set 9 | lata
# Processing Record 31 of Set 9 | boppard
# Processing Record 32 of Set 9 | ust-maya
# Processing Record 33 of Set 9 | high level
# Processing Record 34 of Set 9 | huilong
# Processing Record 35 of Set 9 | provideniya
# City not found, skipping city...
# Processing Record 36 of Set 9 | omsk
# Processing Record 37 of Set 9 | santa isabel do rio negro
# Processing Record 38 of Set 9 | svetlaya
# Processing Record 39 of Set 9 | tikrit
# City not found, skipping city...
# Processing Record 40 of Set 9 | kysyl-syr
# Processing Record 41 of Set 9 | zyryanovsk
# Processing Record 42 of Set 9 | tigil
# Processing Record 43 of Set 9 | ouadda
# Processing Record 44 of Set 9 | sobolevo
# Processing Record 45 of Set 9 | sosnogorsk
# Processing Record 46 of Set 9 | zapolyarnyy
# City not found, skipping city...
# City not found, skipping city...
# Processing Record 47 of Set 9 | kikwit
# Processing Record 48 of Set 9 | porto de moz
# City not found, skipping city...
# Processing Record 49 of Set 9 | bathsheba
# Processing Record 50 of Set 9 | qasigiannguit
# Processing Record 1 of Set 10 | buchanan
# Processing Record 2 of Set 10 | shinyanga
# Processing Record 3 of Set 10 | ratangarh
# Processing Record 4 of Set 10 | tomatlan
# Processing Record 5 of Set 10 | alice springs
# Processing Record 6 of Set 10 | atulayan
# Processing Record 7 of Set 10 | akureyri
# Processing Record 8 of Set 10 | ivanovka
# Processing Record 9 of Set 10 | lenoir city
# Processing Record 10 of Set 10 | orikum
# Processing Record 11 of Set 10 | kulachi
# Processing Record 12 of Set 10 | mamallapuram
# City not found, skipping city...
# Processing Record 13 of Set 10 | maketu
# Processing Record 14 of Set 10 | camacha
# Processing Record 15 of Set 10 | iskateley
# Processing Record 16 of Set 10 | trelew
# Processing Record 17 of Set 10 | guerrero negro
# Processing Record 18 of Set 10 | savannah bight
# Processing Record 19 of Set 10 | benghazi
# Processing Record 20 of Set 10 | avera
# Processing Record 21 of Set 10 | atasu
# Processing Record 22 of Set 10 | haines junction
# Processing Record 23 of Set 10 | iquique
# Processing Record 24 of Set 10 | vila
# Processing Record 25 of Set 10 | pathein
# Processing Record 26 of Set 10 | kiama
# Processing Record 27 of Set 10 | soyo
# Processing Record 28 of Set 10 | eureka
# Processing Record 29 of Set 10 | bowen
# City not found, skipping city...
# Processing Record 30 of Set 10 | atambua
# City not found, skipping city...
# Processing Record 31 of Set 10 | mao
# Processing Record 32 of Set 10 | kamenka
# City not found, skipping city...
# City not found, skipping city...
# Processing Record 33 of Set 10 | ponta delgada
# Processing Record 34 of Set 10 | stokmarknes
# City not found, skipping city...
# Processing Record 35 of Set 10 | cap malheureux
# Processing Record 36 of Set 10 | kuching
# Processing Record 37 of Set 10 | teya
# Processing Record 38 of Set 10 | deputatskiy
# Processing Record 39 of Set 10 | pozo colorado
# Processing Record 40 of Set 10 | tazovskiy
# City not found, skipping city...
# Processing Record 41 of Set 10 | kapuskasing
# Processing Record 42 of Set 10 | abha
# Processing Record 43 of Set 10 | varniai
# Processing Record 44 of Set 10 | port augusta
# Processing Record 45 of Set 10 | neepawa
# Processing Record 46 of Set 10 | aksu
# City not found, skipping city...
# Processing Record 47 of Set 10 | bambous virieux
# Processing Record 48 of Set 10 | katol
# Processing Record 49 of Set 10 | egvekinot
# Processing Record 50 of Set 10 | yala
# Processing Record 1 of Set 11 | gambela
# Processing Record 2 of Set 11 | coihaique
# Processing Record 3 of Set 11 | raudeberg
# City not found, skipping city...
# Processing Record 4 of Set 11 | san carlos
# Processing Record 5 of Set 11 | rovenki
# Processing Record 6 of Set 11 | ilebo
# Processing Record 7 of Set 11 | bilibino
# Processing Record 8 of Set 11 | syasstroy
# Processing Record 9 of Set 11 | hyeres
# Processing Record 10 of Set 11 | south lake tahoe
# Processing Record 11 of Set 11 | arari
# City not found, skipping city...
# Processing Record 12 of Set 11 | exeter
# Processing Record 13 of Set 11 | aripuana
# Processing Record 14 of Set 11 | mabaruma
# Processing Record 15 of Set 11 | terney
# Processing Record 16 of Set 11 | puro
# City not found, skipping city...
# Processing Record 17 of Set 11 | lorengau
# Processing Record 18 of Set 11 | clyde river
# Processing Record 19 of Set 11 | areosa
# Processing Record 20 of Set 11 | mengcheng
# Processing Record 21 of Set 11 | lasa
# Processing Record 22 of Set 11 | centralina
# City not found, skipping city...
# Processing Record 23 of Set 11 | teeli
# Processing Record 24 of Set 11 | novosokolniki
# Processing Record 25 of Set 11 | inuvik
# Processing Record 26 of Set 11 | sao filipe
# Processing Record 27 of Set 11 | gallup
# Processing Record 28 of Set 11 | maniitsoq
# Processing Record 29 of Set 11 | las palmas
# City not found, skipping city...
# Processing Record 30 of Set 11 | yumen
# Processing Record 31 of Set 11 | aranos
# Processing Record 32 of Set 11 | naze
# Processing Record 33 of Set 11 | hambantota
# Processing Record 34 of Set 11 | havre-saint-pierre
# Processing Record 35 of Set 11 | macau
# Processing Record 36 of Set 11 | tombouctou
# Processing Record 37 of Set 11 | amlame
# Processing Record 38 of Set 11 | itapirapua
# Processing Record 39 of Set 11 | ambilobe
# Processing Record 40 of Set 11 | saint-georges
# Processing Record 41 of Set 11 | shellbrook
# Processing Record 42 of Set 11 | agadez
# Processing Record 43 of Set 11 | mahibadhoo
# City not found, skipping city...
# Processing Record 44 of Set 11 | karratha
# Processing Record 45 of Set 11 | kibara
# Processing Record 46 of Set 11 | yulara
# Processing Record 47 of Set 11 | midland
# Processing Record 48 of Set 11 | birao
# Processing Record 49 of Set 11 | petropavlovka
# Processing Record 50 of Set 11 | shirokiy
# City not found, skipping city...
# Processing Record 1 of Set 12 | boshnyakovo
# Processing Record 2 of Set 12 | bonavista
# Processing Record 3 of Set 12 | tall kayf
# Processing Record 4 of Set 12 | hofn
# Processing Record 5 of Set 12 | vila velha
# Processing Record 6 of Set 12 | antalaha
# City not found, skipping city...
# Processing Record 7 of Set 12 | pangkalanbuun
# City not found, skipping city...
# Processing Record 8 of Set 12 | casisang
# Processing Record 9 of Set 12 | chipinge
# Processing Record 10 of Set 12 | nabire
# Processing Record 11 of Set 12 | sarakhs
# Processing Record 12 of Set 12 | livingston
# City not found, skipping city...
# Processing Record 13 of Set 12 | soavinandriana
# Processing Record 14 of Set 12 | valparaiso
# Processing Record 15 of Set 12 | sargatskoye
# Processing Record 16 of Set 12 | erdenet
# City not found, skipping city...
# Processing Record 17 of Set 12 | jiaohe
# City not found, skipping city...
# Processing Record 18 of Set 12 | gien
# -----------------------
# Data Retrieval Complete
# -----------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dic = {
    "City": cities_owm,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date": date,
    "Humidity": humidity,
    "Lat": lat,
    "Lng": lng,
    "Max Temp": max_temp,
    "Min Temp": min_temp,
    "Wind Speed": wind_speed
}
# weather_dic

# %%
weather_df = pd.DataFrame(weather_dic)
weather_df.head()
# Out:
#          City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     Rikitea          89      PF  1569783520        76 -23.12 -134.97
# 1  Naryan-Mar         100      RU  1569783520        98  67.67   53.09
# 2      Hobart          75      AU  1569783513        97 -42.88  147.33
# 3   Harnosand           0      SE  1569783521       100  62.63   17.94
# 4     Ushuaia          75      AR  1569783521        75 -54.81  -68.31
#
#    Max Temp  Min Temp  Wind Speed
# 0     21.65     21.65        4.18
# 1      3.65      3.65        2.80
# 2      8.00      5.56        4.60
# 3     11.11     10.00        1.50
# 4      8.00      8.00        1.37

# %%
weather_df.count()
# Out:
# City          567
# Cloudiness    567
# Country       567
# Date          567
# Humidity      567
# Lat           567
# Lng           567
# Max Temp      567
# Min Temp      567
# Wind Speed    567
# dtype: int64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Max Temp"],edgecolors="black",facecolors="red")
plt.title("City Latitude vs. Max Temperature (09/29/19)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("Figures/fig1.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Humidity"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Humidity (09/29/19)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("Figures/fig2.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Cloudiness"],edgecolors="black",facecolors="darkgrey")
plt.title("City Latitude vs. Cloudiness (09/29/19)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("Figures/fig3.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Wind Speed"],edgecolors="black",facecolors="lightgreen")
plt.title("City Latitude vs. Wind Speed (09/29/19)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (kmph)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("Figures/fig4.png")
plt.show()
